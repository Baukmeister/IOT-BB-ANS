# %% [markdown]
# # Analysis of WIDSM data

# %%
from util.WIDSMDataLoader import WISDMDataset

dataSet = WISDMDataset("data/wisdm-dataset/raw", discretize=True, scaling_factor=100, shift=True, data_set_size="all")
WISDMdf = dataSet.WISDMdf
# Out:
# Loading data from 'data/wisdm-dataset/raw/phone/accel' ...
# 100%|██████████| 52/52 [00:13<00:00,  3.80it/s]
# Loading data from 'data/wisdm-dataset/raw/phone/gyro' ...
# 100%|██████████| 52/52 [00:14<00:00,  3.60it/s]
# Loading data from 'data/wisdm-dataset/raw/watch/accel' ...
# 100%|██████████| 52/52 [00:17<00:00,  2.94it/s]
# Loading data from 'data/wisdm-dataset/raw/watch/gyro' ...
# 100%|██████████| 52/52 [00:28<00:00,  1.85it/s]

# %%
WISDMdf.hist(bins=50, figsize=(10,10))
WISDMdf.describe()
# Out:
#                user          time             x             y             z
# count  1.563043e+07  1.563043e+07  1.563043e+07  1.563043e+07  1.563043e+07
# mean   1.626267e+03  5.904473e+14  7.860915e+03  7.687214e+03  7.903705e+03
# std    1.478817e+01  6.034457e+14  4.792884e+02  5.025264e+02  3.970898e+02
# min    1.600000e+03  2.681027e+11  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.614000e+03  1.079145e+14  7.706000e+03  7.432000e+03  7.784000e+03
# 50%    1.627000e+03  3.704818e+14  7.848000e+03  7.835000e+03  7.848000e+03
# 75%    1.639000e+03  9.407683e+14  7.977000e+03  7.860000e+03  8.027000e+03
# max    1.650000e+03  2.724599e+15  1.569600e+04  1.428900e+04  1.475600e+04
