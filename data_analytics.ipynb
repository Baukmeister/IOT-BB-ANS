# %% [markdown]
# # Analysis of WIDSM data

# %%
from util.WIDSMDataLoader import WISDMDataset

dataSet = WISDMDataset("data/wisdm-dataset/raw")
WISDMdf = dataSet.WISDMdf
# Out:
# Loading data from 'data/wisdm-dataset/raw/phone/accel' ...
# 100%|██████████| 52/52 [00:42<00:00,  1.23it/s]

# %%
WISDMdf.hist(bins=30, figsize=(10,10))
WISDMdf.describe()
# Out:
#                user          time             x             y             z
# count  4.804403e+06  4.804403e+06  4.804403e+06  4.804403e+06  4.804403e+06
# mean   1.627610e+03  5.960486e+14  1.415401e-01 -1.685717e+00  3.503554e-01
# std    1.500282e+01  5.283930e+14  5.849490e+00  6.883070e+00  5.124781e+00
# min    1.600000e+03  2.681027e+11 -7.847761e+01 -7.847761e+01 -7.847761e+01
# 25%    1.614000e+03  1.696225e+14 -3.959411e+00 -7.369475e+00 -2.876419e+00
# 50%    1.628000e+03  4.432069e+14  9.463501e-02 -2.085799e+00  3.813171e-02
# 75%    1.642000e+03  1.130426e+15  4.406906e+00  2.477570e+00  4.105225e+00
# max    1.650000e+03  1.819803e+15  7.847761e+01  6.441166e+01  6.908195e+01
