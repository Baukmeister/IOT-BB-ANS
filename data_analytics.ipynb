# %% [markdown]
# # Analysis of WIDSM data

# %%
from util.WIDSMDataLoader import WISDMDataset

dataSet = WISDMDataset("data/wisdm-dataset/raw", discretize=True)
WISDMdf = dataSet.WISDMdf
# Out:
# Loading data from 'data/wisdm-dataset/raw/phone/accel' ...
# 100%|██████████| 52/52 [00:08<00:00,  5.81it/s]

# %%
WISDMdf.hist(bins=50, figsize=(10,10))
WISDMdf.describe()
# Out:
#                user          time             x             y             z
# count  4.804403e+06  4.804403e+06  4.804403e+06  4.804403e+06  4.804403e+06
# mean   1.627610e+03  5.960486e+14  8.014927e+01  7.831616e+01  8.035057e+01
# std    1.500282e+01  5.283930e+14  5.852158e+00  6.895588e+00  5.136520e+00
# min    1.600000e+03  2.681027e+11  2.000000e+00  2.000000e+00  2.000000e+00
# 25%    1.614000e+03  1.696225e+14  7.600000e+01  7.300000e+01  7.700000e+01
# 50%    1.628000e+03  4.432069e+14  8.000000e+01  7.800000e+01  8.000000e+01
# 75%    1.642000e+03  1.130426e+15  8.400000e+01  8.200000e+01  8.400000e+01
# max    1.650000e+03  1.819803e+15  1.580000e+02  1.440000e+02  1.490000e+02
