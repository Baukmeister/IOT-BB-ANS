# %% [markdown]
# # Analysis of WIDSM data

# %%
from util.WIDSMDataLoader import WISDMDataset

dataSet = WISDMDataset("data/wisdm-dataset/raw", discretize=True, scaling_factor=1, shift=True, data_set_size="all", caching=False)
WISDMdf = dataSet.WISDMdf
# Out:
# Loading data from 'data/wisdm-dataset/raw/phone/accel' ...
# 100%|██████████| 52/52 [00:09<00:00,  5.38it/s]
# Loading data from 'data/wisdm-dataset/raw/phone/gyro' ...
# 100%|██████████| 52/52 [00:10<00:00,  4.74it/s]
# Loading data from 'data/wisdm-dataset/raw/watch/accel' ...
# 100%|██████████| 52/52 [00:14<00:00,  3.66it/s]
# Loading data from 'data/wisdm-dataset/raw/watch/gyro' ...
# 100%|██████████| 52/52 [00:17<00:00,  3.01it/s]

# %%
WISDMdf.hist(bins=50, figsize=(10,10))
WISDMdf.describe()
# Out:
#                user          time             x             y             z
# count  1.563043e+07  1.563043e+07  1.563043e+07  1.563043e+07  1.563043e+07
# mean   1.626267e+03  5.904473e+14  7.813235e+01  7.639340e+01  7.855619e+01
# std    1.478817e+01  6.034457e+14  4.800819e+00  5.032039e+00  3.983048e+00
# min    1.600000e+03  2.681027e+11  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.614000e+03  1.079145e+14  7.700000e+01  7.400000e+01  7.700000e+01
# 50%    1.627000e+03  3.704818e+14  7.800000e+01  7.800000e+01  7.800000e+01
# 75%    1.639000e+03  9.407683e+14  7.900000e+01  7.800000e+01  8.000000e+01
# max    1.650000e+03  2.724599e+15  1.560000e+02  1.420000e+02  1.470000e+02

# %% [markdown]
# # Analysis of Intel Lab Data

# %%
from util.IntelLabDataLoader import IntelLabDataset

dataSet = IntelLabDataset("data/IntelLabData", discretize=True, scaling_factor=1, caching=False)
HouseholdPowerDf= dataSet.IntelDataDf
HouseholdPowerDf.hist(bins=50, figsize=(10, 10))
HouseholdPowerDf.describe()
# Out:
#               epoch       mote_id   temperature      humidity         light  \
# count  2.313682e+06  2.313156e+06  2.312781e+06  2.312780e+06  2.313682e+06
# mean   3.303993e+04  2.854412e+01  3.557843e+01  3.439434e+01  3.906360e+02
# std    1.836852e+04  5.062408e+01  2.939887e+01  1.495857e+01  5.344074e+02
# min    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.757200e+04  1.700000e+01  2.000000e+01  3.200000e+01  1.800000e+01
# 50%    3.332700e+04  2.900000e+01  2.200000e+01  3.900000e+01  1.440000e+02
# 75%    4.778900e+04  4.100000e+01  2.700000e+01  4.400000e+01  5.080000e+02
# max    6.553500e+04  6.540700e+04  1.000000e+02  1.000000e+02  1.847000e+03
#
#             voltage
# count  2.313156e+06
# mean   2.557436e+00
# std    4.968269e-01
# min    0.000000e+00
# 25%    2.000000e+00
# 50%    3.000000e+00
# 75%    3.000000e+00
# max    1.900000e+01

# %%
from util.HouseholdPowerDataLoader import HouseholdPowerDataset

dataSet = HouseholdPowerDataset("data/household_power_consumption", discretize=True, scaling_factor=1, caching=False)
HouseholdPowerDf= dataSet.HouseholdPowerDf
HouseholdPowerDf.hist(bins=50, figsize=(10, 10))
HouseholdPowerDf.describe()
# Out:
#        Global_active_power  Global_reactive_power       Voltage  \
# count         2.075259e+06           2.075259e+06  2.075259e+06
# mean          9.423590e-01           7.692052e-03  2.378255e+02
# std           1.176773e+00           8.736640e-02  2.697186e+01
# min           0.000000e+00           0.000000e+00  0.000000e+00
# 25%           0.000000e+00           0.000000e+00  2.390000e+02
# 50%           1.000000e+00           0.000000e+00  2.410000e+02
# 75%           2.000000e+00           0.000000e+00  2.430000e+02
# max           1.100000e+01           1.000000e+00  2.540000e+02
#
#        Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# count      2.075259e+06    2.075259e+06    2.075259e+06    2.075259e+06
# mean       4.565367e+00    1.107879e+00    1.282265e+00    6.377598e+00
# std        4.458031e+00    6.115669e+00    5.787271e+00    8.414871e+00
# min        0.000000e+00    0.000000e+00    0.000000e+00    0.000000e+00
# ...
